# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import tree, linear_model
from sklearn.metrics import accuracy_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from fbprophet import Prophet
# %matplotlib inline
pd.plotting.register_matplotlib_converters()

# %%
data = pd.read_csv('./crime.csv')

# %%
data.head(10)
# Out:
#                                 TYPE  YEAR  MONTH  DAY  HOUR  MINUTE  \
# 0                        Other Theft  2003      5   12  16.0    15.0
# 1                        Other Theft  2003      5    7  15.0    20.0
# 2                        Other Theft  2003      4   23  16.0    40.0
# 3                        Other Theft  2003      4   20  11.0    15.0
# 4                        Other Theft  2003      4   12  17.0    45.0
# 5                        Other Theft  2003      3   26  20.0    45.0
# 6  Break and Enter Residential/Other  2003      3   10  12.0     0.0
# 7                           Mischief  2003      6   28   4.0    13.0
# 8                        Other Theft  2003      2   16   9.0     2.0
# 9  Break and Enter Residential/Other  2003      7    9  18.0    15.0
#
#        HUNDRED_BLOCK       NEIGHBOURHOOD          X           Y   Latitude  \
# 0   9XX TERMINAL AVE          Strathcona  493906.50  5457452.47  49.269802
# 1   9XX TERMINAL AVE          Strathcona  493906.50  5457452.47  49.269802
# 2   9XX TERMINAL AVE          Strathcona  493906.50  5457452.47  49.269802
# 3   9XX TERMINAL AVE          Strathcona  493906.50  5457452.47  49.269802
# 4   9XX TERMINAL AVE          Strathcona  493906.50  5457452.47  49.269802
# 5   9XX TERMINAL AVE          Strathcona  493906.50  5457452.47  49.269802
# 6  63XX WILTSHIRE ST          Kerrisdale  489325.58  5452817.95  49.228051
# 7    40XX W 19TH AVE   Dunbar-Southlands  485903.09  5455883.77  49.255559
# 8   9XX TERMINAL AVE          Strathcona  493906.50  5457452.47  49.269802
# 9     18XX E 3RD AVE  Grandview-Woodland  495078.19  5457221.38  49.267734
#
#     Longitude
# 0 -123.083763
# 1 -123.083763
# 2 -123.083763
# 3 -123.083763
# 4 -123.083763
# 5 -123.083763
# 6 -123.146610
# 7 -123.193725
# 8 -123.083763
# 9 -123.067654

# %%
data.head().T
# Out:
#                               0                 1                 2  \
# TYPE                Other Theft       Other Theft       Other Theft
# YEAR                       2003              2003              2003
# MONTH                         5                 5                 4
# DAY                          12                 7                23
# HOUR                         16                15                16
# MINUTE                       15                20                40
# HUNDRED_BLOCK  9XX TERMINAL AVE  9XX TERMINAL AVE  9XX TERMINAL AVE
# NEIGHBOURHOOD        Strathcona        Strathcona        Strathcona
# X                        493906            493906            493906
# Y                   5.45745e+06       5.45745e+06       5.45745e+06
# Latitude                49.2698           49.2698           49.2698
# Longitude              -123.084          -123.084          -123.084
#
#                               3                 4
# TYPE                Other Theft       Other Theft
# YEAR                       2003              2003
# MONTH                         4                 4
# DAY                          20                12
# HOUR                         11                17
# MINUTE                       15                45
# HUNDRED_BLOCK  9XX TERMINAL AVE  9XX TERMINAL AVE
# NEIGHBOURHOOD        Strathcona        Strathcona
# X                        493906            493906
# Y                   5.45745e+06       5.45745e+06
# Latitude                49.2698           49.2698
# Longitude              -123.084          -123.084

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 530652 entries, 0 to 530651
# Data columns (total 12 columns):
# TYPE             530652 non-null object
# YEAR             530652 non-null int64
# MONTH            530652 non-null int64
# DAY              530652 non-null int64
# HOUR             476290 non-null float64
# MINUTE           476290 non-null float64
# HUNDRED_BLOCK    530639 non-null object
# NEIGHBOURHOOD    474028 non-null object
# X                530652 non-null float64
# Y                530652 non-null float64
# Latitude         530652 non-null float64
# Longitude        530652 non-null float64
# dtypes: float64(6), int64(3), object(3)
# memory usage: 48.6+ MB

# %%
data = data.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 474015 entries, 0 to 530651
# Data columns (total 12 columns):
# TYPE             474015 non-null object
# YEAR             474015 non-null int64
# MONTH            474015 non-null int64
# DAY              474015 non-null int64
# HOUR             474015 non-null float64
# MINUTE           474015 non-null float64
# HUNDRED_BLOCK    474015 non-null object
# NEIGHBOURHOOD    474015 non-null object
# X                474015 non-null float64
# Y                474015 non-null float64
# Latitude         474015 non-null float64
# Longitude        474015 non-null float64
# dtypes: float64(6), int64(3), object(3)
# memory usage: 47.0+ MB

# %%
data.head()
# Out:
#           TYPE  YEAR  MONTH  DAY  HOUR  MINUTE     HUNDRED_BLOCK  \
# 0  Other Theft  2003      5   12  16.0    15.0  9XX TERMINAL AVE
# 1  Other Theft  2003      5    7  15.0    20.0  9XX TERMINAL AVE
# 2  Other Theft  2003      4   23  16.0    40.0  9XX TERMINAL AVE
# 3  Other Theft  2003      4   20  11.0    15.0  9XX TERMINAL AVE
# 4  Other Theft  2003      4   12  17.0    45.0  9XX TERMINAL AVE
#
#   NEIGHBOURHOOD         X           Y   Latitude   Longitude
# 0    Strathcona  493906.5  5457452.47  49.269802 -123.083763
# 1    Strathcona  493906.5  5457452.47  49.269802 -123.083763
# 2    Strathcona  493906.5  5457452.47  49.269802 -123.083763
# 3    Strathcona  493906.5  5457452.47  49.269802 -123.083763
# 4    Strathcona  493906.5  5457452.47  49.269802 -123.083763

# %%
data['DATE'] = pd.to_datetime({'year':data['YEAR'], 'month':data['MONTH'], 'day':data['DAY']})

# %%
data['DAY_OF_WEEK'] = data['DATE'].dt.dayofweek

# %%
data.index = pd.DatetimeIndex(data['DATE'])

# %%
data['TYPE'].value_counts().sort_index()
# Out:
# Break and Enter Commercial                                 33841
# Break and Enter Residential/Other                          60856
# Mischief                                                   70157
# Other Theft                                                52160
# Theft from Vehicle                                        170889
# Theft of Bicycle                                           25620
# Theft of Vehicle                                           38351
# Vehicle Collision or Pedestrian Struck (with Fatality)       254
# Vehicle Collision or Pedestrian Struck (with Injury)       21887
# Name: TYPE, dtype: int64

# %%
def get_common_category(ctype):
    if 'Theft' in ctype:
        return 'Theft'
    elif 'Break' in ctype:
        return 'Break and Enter'
    elif 'Collision' in ctype:
        return 'Vehicle Collision'
    else:
        return 'Others'

# %%
data['CATEGORY'] = data['TYPE'].apply(get_common_category)

# %%
data.head()
# Out:
#                    TYPE  YEAR  MONTH  DAY  HOUR  MINUTE     HUNDRED_BLOCK  \
# DATE
# 2003-05-12  Other Theft  2003      5   12  16.0    15.0  9XX TERMINAL AVE
# 2003-05-07  Other Theft  2003      5    7  15.0    20.0  9XX TERMINAL AVE
# 2003-04-23  Other Theft  2003      4   23  16.0    40.0  9XX TERMINAL AVE
# 2003-04-20  Other Theft  2003      4   20  11.0    15.0  9XX TERMINAL AVE
# 2003-04-12  Other Theft  2003      4   12  17.0    45.0  9XX TERMINAL AVE
#
#            NEIGHBOURHOOD         X           Y   Latitude   Longitude  \
# DATE
# 2003-05-12    Strathcona  493906.5  5457452.47  49.269802 -123.083763
# 2003-05-07    Strathcona  493906.5  5457452.47  49.269802 -123.083763
# 2003-04-23    Strathcona  493906.5  5457452.47  49.269802 -123.083763
# 2003-04-20    Strathcona  493906.5  5457452.47  49.269802 -123.083763
# 2003-04-12    Strathcona  493906.5  5457452.47  49.269802 -123.083763
#
#                  DATE  DAY_OF_WEEK CATEGORY
# DATE
# 2003-05-12 2003-05-12            0    Theft
# 2003-05-07 2003-05-07            2    Theft
# 2003-04-23 2003-04-23            2    Theft
# 2003-04-20 2003-04-20            6    Theft
# 2003-04-12 2003-04-12            5    Theft

# %%
data = data[data['CATEGORY'] != 'Vehicle Collision']

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 451874 entries, 2003-05-12 to 2017-06-05
# Data columns (total 15 columns):
# TYPE             451874 non-null object
# YEAR             451874 non-null int64
# MONTH            451874 non-null int64
# DAY              451874 non-null int64
# HOUR             451874 non-null float64
# MINUTE           451874 non-null float64
# HUNDRED_BLOCK    451874 non-null object
# NEIGHBOURHOOD    451874 non-null object
# X                451874 non-null float64
# Y                451874 non-null float64
# Latitude         451874 non-null float64
# Longitude        451874 non-null float64
# DATE             451874 non-null datetime64[ns]
# DAY_OF_WEEK      451874 non-null int64
# CATEGORY         451874 non-null object
# dtypes: datetime64[ns](1), float64(6), int64(4), object(4)
# memory usage: 55.2+ MB

# %%
data.head(10)
# Out:
#                                          TYPE  YEAR  MONTH  DAY  HOUR  MINUTE  \
# DATE
# 2003-05-12                        Other Theft  2003      5   12  16.0    15.0
# 2003-05-07                        Other Theft  2003      5    7  15.0    20.0
# 2003-04-23                        Other Theft  2003      4   23  16.0    40.0
# 2003-04-20                        Other Theft  2003      4   20  11.0    15.0
# 2003-04-12                        Other Theft  2003      4   12  17.0    45.0
# 2003-03-26                        Other Theft  2003      3   26  20.0    45.0
# 2003-03-10  Break and Enter Residential/Other  2003      3   10  12.0     0.0
# 2003-06-28                           Mischief  2003      6   28   4.0    13.0
# 2003-02-16                        Other Theft  2003      2   16   9.0     2.0
# 2003-07-09  Break and Enter Residential/Other  2003      7    9  18.0    15.0
#
#                 HUNDRED_BLOCK       NEIGHBOURHOOD          X           Y  \
# DATE
# 2003-05-12   9XX TERMINAL AVE          Strathcona  493906.50  5457452.47
# 2003-05-07   9XX TERMINAL AVE          Strathcona  493906.50  5457452.47
# 2003-04-23   9XX TERMINAL AVE          Strathcona  493906.50  5457452.47
# 2003-04-20   9XX TERMINAL AVE          Strathcona  493906.50  5457452.47
# 2003-04-12   9XX TERMINAL AVE          Strathcona  493906.50  5457452.47
# 2003-03-26   9XX TERMINAL AVE          Strathcona  493906.50  5457452.47
# 2003-03-10  63XX WILTSHIRE ST          Kerrisdale  489325.58  5452817.95
# 2003-06-28    40XX W 19TH AVE   Dunbar-Southlands  485903.09  5455883.77
# 2003-02-16   9XX TERMINAL AVE          Strathcona  493906.50  5457452.47
# 2003-07-09     18XX E 3RD AVE  Grandview-Woodland  495078.19  5457221.38
#
#              Latitude   Longitude       DATE  DAY_OF_WEEK         CATEGORY
# DATE
# 2003-05-12  49.269802 -123.083763 2003-05-12            0            Theft
# 2003-05-07  49.269802 -123.083763 2003-05-07            2            Theft
# 2003-04-23  49.269802 -123.083763 2003-04-23            2            Theft
# 2003-04-20  49.269802 -123.083763 2003-04-20            6            Theft
# 2003-04-12  49.269802 -123.083763 2003-04-12            5            Theft
# 2003-03-26  49.269802 -123.083763 2003-03-26            2            Theft
# 2003-03-10  49.228051 -123.146610 2003-03-10            0  Break and Enter
# 2003-06-28  49.255559 -123.193725 2003-06-28            5           Others
# 2003-02-16  49.269802 -123.083763 2003-02-16            6            Theft
# 2003-07-09  49.267734 -123.067654 2003-07-09            2  Break and Enter

# %%
data.resample('D').size().idxmax()
# Out:
# Timestamp('2011-06-15 00:00:00', freq='D')

# %%
plt.figure(figsize=(13,5))
data.resample('D').size().plot(label='Crimes per day')
plt.title('Total crimes per day', fontsize=14)
plt.xlabel('Date')
plt.ylabel('Number')
plt.tick_params(labelsize=14)
plt.legend(prop={'size':16})

# %%
plt.figure(figsize=(13,5))
data.resample('M').size().plot(label='Per month')
data.resample('M').size().rolling(window=12).mean().plot(color='red', linewidth=5, label='Average')
plt.title('Total crimes per month', fontsize=16)
plt.xlabel('')
plt.legend(prop={'size':16})
plt.tick_params(labelsize=16)

# %%
crimes_pivot_table = data.pivot_table(values='TYPE', index='CATEGORY', columns='MONTH', aggfunc=len)

crimes_scaled = pd.DataFrame(crimes_pivot_table.iloc[0] / crimes_pivot_table.iloc[0].max())

for i in [2,1]:
    crimes_scaled[crimes_pivot_table.index[i]] =  pd.DataFrame(crimes_pivot_table.iloc[i] / crimes_pivot_table.iloc[i].max())
                    
plt.figure(figsize=(4,4))
plt.title('Month and Category heatmap', fontsize=14)
plt.tick_params(labelsize=12)
sns.heatmap(crimes_scaled, cmap='seismic', linecolor='grey',linewidths=0.1, cbar=False)

# %%
days = ['Monday','Tuesday','Wednesday',  'Thursday', 'Friday', 'Saturday', 'Sunday']
data.groupby(data['DAY_OF_WEEK']).size().plot(kind='barh')
plt.ylabel('Days of the week')
plt.yticks(np.arange(7), days)
plt.xlabel('Number of crimes')
plt.title('Number of Crimes by Day of the Week')
plt.show()

# %%
crimes_pivot_table = data.pivot_table(values='TYPE', index='CATEGORY', columns='DAY_OF_WEEK', aggfunc=len)

crimes_scaled = pd.DataFrame(crimes_pivot_table.iloc[0] / crimes_pivot_table.iloc[0].max())

for i in [2,1]:
    crimes_scaled[crimes_pivot_table.index[i]] = crimes_pivot_table.iloc[i] / crimes_pivot_table.iloc[i].max()
                    
crimes_scaled.index = ['Mon','Tue','Wed','Thu','Fri','Sat','Sun']

plt.figure(figsize=(4,4))
plt.title('Day of the Week and Category heatmap', fontsize=14)
plt.tick_params(labelsize=12)
sns.heatmap(crimes_scaled, cmap='seismic', linecolor='grey',linewidths=0.1, cbar=False)

# %%
crimes_pivot_table = data.pivot_table(values='TYPE', index='CATEGORY', columns='HOUR', aggfunc=len)

crimes_scaled = pd.DataFrame(crimes_pivot_table.iloc[0] / crimes_pivot_table.iloc[0].max())

for i in [2,1]:
    crimes_scaled[crimes_pivot_table.index[i]] =  pd.DataFrame(crimes_pivot_table.iloc[i] / crimes_pivot_table.iloc[i].max())
                    
plt.figure(figsize=(5,5))
plt.title('Hour and Category heatmap', fontsize=14)
plt.tick_params(labelsize=12)
sns.heatmap(crimes_scaled, cmap='seismic', linecolor='grey',linewidths=0.1, cbar=False)

# %%
data['NeighbourhoodID'] = data.groupby('NEIGHBOURHOOD').ngroup().add(1)

# %%
print(data)
# Out:
#                                          TYPE  YEAR  MONTH  DAY  HOUR  MINUTE  \
# DATE
# 2003-05-12                        Other Theft  2003      5   12  16.0    15.0
# 2003-05-07                        Other Theft  2003      5    7  15.0    20.0
# 2003-04-23                        Other Theft  2003      4   23  16.0    40.0
# 2003-04-20                        Other Theft  2003      4   20  11.0    15.0
# 2003-04-12                        Other Theft  2003      4   12  17.0    45.0
# ...                                       ...   ...    ...  ...   ...     ...
# 2017-06-17  Break and Enter Residential/Other  2017      6   17  12.0    29.0
# 2017-01-18                           Mischief  2017      1   18  14.0    44.0
# 2017-03-03  Break and Enter Residential/Other  2017      3    3   9.0    16.0
# 2017-05-29                           Mischief  2017      5   29  22.0    30.0
# 2017-06-05                 Theft from Vehicle  2017      6    5  17.0     0.0
#
#                  HUNDRED_BLOCK              NEIGHBOURHOOD          X  \
# DATE
# 2003-05-12    9XX TERMINAL AVE                 Strathcona  493906.50
# 2003-05-07    9XX TERMINAL AVE                 Strathcona  493906.50
# 2003-04-23    9XX TERMINAL AVE                 Strathcona  493906.50
# 2003-04-20    9XX TERMINAL AVE                 Strathcona  493906.50
# 2003-04-12    9XX TERMINAL AVE                 Strathcona  493906.50
# ...                        ...                        ...        ...
# 2017-06-17      30XX W 7TH AVE                  Kitsilano  487435.85
# 2017-01-18  14XX E HASTINGS ST         Grandview-Woodland  494563.75
# 2017-03-03      31XX ADANAC ST           Hastings-Sunrise  497265.49
# 2017-05-29      14XX E 7TH AVE         Grandview-Woodland  494533.97
# 2017-06-05     8XX HAMILTON ST  Central Business District  491487.85
#
#                      Y   Latitude   Longitude       DATE  DAY_OF_WEEK  \
# DATE
# 2003-05-12  5457452.47  49.269802 -123.083763 2003-05-12            0
# 2003-05-07  5457452.47  49.269802 -123.083763 2003-05-07            2
# 2003-04-23  5457452.47  49.269802 -123.083763 2003-04-23            2
# 2003-04-20  5457452.47  49.269802 -123.083763 2003-04-20            6
# 2003-04-12  5457452.47  49.269802 -123.083763 2003-04-12            5
# ...                ...        ...         ...        ...          ...
# 2017-06-17  5457028.69  49.265891 -123.172698 2017-06-17            5
# 2017-01-18  5458727.40  49.281276 -123.074746 2017-01-18            2
# 2017-03-03  5458296.71  49.277420 -123.037595 2017-03-03            4
# 2017-05-29  5456824.97  49.264163 -123.075129 2017-05-29            0
# 2017-06-05  5458385.78  49.278168 -123.117031 2017-06-05            0
#
#                    CATEGORY  NeighbourhoodID
# DATE
# 2003-05-12            Theft               20
# 2003-05-07            Theft               20
# 2003-04-23            Theft               20
# 2003-04-20            Theft               20
# 2003-04-12            Theft               20
# ...                     ...              ...
# 2017-06-17  Break and Enter               10
# 2017-01-18           Others                5
# 2017-03-03  Break and Enter                6
# 2017-05-29           Others                5
# 2017-06-05            Theft                2
#
# [451874 rows x 16 columns]

# %%
data_for_dt = data

# %%
X = data_for_dt[['YEAR', 'MONTH', 'DAY','HOUR', 'NeighbourhoodID']]

# %%
Y = data_for_dt[['CATEGORY']]

# %%
X_train , X_test, Y_train, Y_test = train_test_split( X, Y, test_size = 0.3, random_state = 5)

# %%
print(X_train.shape, Y_train.shape)
# Out:
# (316311, 5) (316311, 1)

# %%
print(X_test.shape, Y_test.shape)
# Out:
# (135563, 5) (135563, 1)

# %%
clf_gini = DecisionTreeClassifier(criterion = "gini", random_state = 5,
                               max_depth=5, min_samples_leaf=8)

# %%
clf_gini.fit(X_train, Y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=5, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=8, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=5, splitter='best')

# %%
Y_pred_gini = clf_gini.predict(X_test)

# %%
print ('Accuracy of DT using gini - ', accuracy_score(Y_test,Y_pred_gini) * 100, '%')
# Out:
# Accuracy of DT using gini -  63.949602767716854 %

# %%
clf_entropy = DecisionTreeClassifier(criterion = "entropy", random_state = 5,
                                    max_depth=5, min_samples_leaf=8)

# %%
clf_entropy.fit(X_train, Y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='entropy',
#                        max_depth=5, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=8, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=5, splitter='best')

# %%
Y_pred_entropy = clf_entropy.predict(X_test)

# %%
print ('Accuracy of DT using entropy - ', accuracy_score(Y_test,Y_pred_entropy) * 100, '%')
# Out:
# Accuracy of DT using entropy -  63.94001313042644 %

# %%
clf_gini.predict([[2003,5,12,16.0,20]])
# Out:
# array(['Theft'], dtype=object)

# %%
clf_entropy.predict([[2003,5,12,16.0,20]])
# Out:
# array(['Theft'], dtype=object)

# %%
data['CategoryID'] = data.groupby('CATEGORY').ngroup().add(1)
print(data)
# Out:
#                                          TYPE  YEAR  MONTH  DAY  HOUR  MINUTE  \
# DATE
# 2003-05-12                        Other Theft  2003      5   12  16.0    15.0
# 2003-05-07                        Other Theft  2003      5    7  15.0    20.0
# 2003-04-23                        Other Theft  2003      4   23  16.0    40.0
# 2003-04-20                        Other Theft  2003      4   20  11.0    15.0
# 2003-04-12                        Other Theft  2003      4   12  17.0    45.0
# ...                                       ...   ...    ...  ...   ...     ...
# 2017-06-17  Break and Enter Residential/Other  2017      6   17  12.0    29.0
# 2017-01-18                           Mischief  2017      1   18  14.0    44.0
# 2017-03-03  Break and Enter Residential/Other  2017      3    3   9.0    16.0
# 2017-05-29                           Mischief  2017      5   29  22.0    30.0
# 2017-06-05                 Theft from Vehicle  2017      6    5  17.0     0.0
#
#                  HUNDRED_BLOCK              NEIGHBOURHOOD          X  \
# DATE
# 2003-05-12    9XX TERMINAL AVE                 Strathcona  493906.50
# 2003-05-07    9XX TERMINAL AVE                 Strathcona  493906.50
# 2003-04-23    9XX TERMINAL AVE                 Strathcona  493906.50
# 2003-04-20    9XX TERMINAL AVE                 Strathcona  493906.50
# 2003-04-12    9XX TERMINAL AVE                 Strathcona  493906.50
# ...                        ...                        ...        ...
# 2017-06-17      30XX W 7TH AVE                  Kitsilano  487435.85
# 2017-01-18  14XX E HASTINGS ST         Grandview-Woodland  494563.75
# 2017-03-03      31XX ADANAC ST           Hastings-Sunrise  497265.49
# 2017-05-29      14XX E 7TH AVE         Grandview-Woodland  494533.97
# 2017-06-05     8XX HAMILTON ST  Central Business District  491487.85
#
#                      Y   Latitude   Longitude       DATE  DAY_OF_WEEK  \
# DATE
# 2003-05-12  5457452.47  49.269802 -123.083763 2003-05-12            0
# 2003-05-07  5457452.47  49.269802 -123.083763 2003-05-07            2
# 2003-04-23  5457452.47  49.269802 -123.083763 2003-04-23            2
# 2003-04-20  5457452.47  49.269802 -123.083763 2003-04-20            6
# 2003-04-12  5457452.47  49.269802 -123.083763 2003-04-12            5
# ...                ...        ...         ...        ...          ...
# 2017-06-17  5457028.69  49.265891 -123.172698 2017-06-17            5
# 2017-01-18  5458727.40  49.281276 -123.074746 2017-01-18            2
# 2017-03-03  5458296.71  49.277420 -123.037595 2017-03-03            4
# 2017-05-29  5456824.97  49.264163 -123.075129 2017-05-29            0
# 2017-06-05  5458385.78  49.278168 -123.117031 2017-06-05            0
#
#                    CATEGORY  NeighbourhoodID  CategoryID
# DATE
# 2003-05-12            Theft               20           3
# 2003-05-07            Theft               20           3
# 2003-04-23            Theft               20           3
# 2003-04-20            Theft               20           3
# 2003-04-12            Theft               20           3
# ...                     ...              ...         ...
# 2017-06-17  Break and Enter               10           1
# 2017-01-18           Others                5           2
# 2017-03-03  Break and Enter                6           1
# 2017-05-29           Others                5           2
# 2017-06-05            Theft                2           3
#
# [451874 rows x 17 columns]

# %%
X = data_for_dt[['CategoryID', 'NeighbourhoodID', 'Latitude', 'Longitude']]
Y = data_for_dt[['HOUR']]

# %%
X_train , X_test, Y_train, Y_test = train_test_split( X, Y, test_size = 0.3, random_state = 5)

# %%
reg = linear_model.LinearRegression()

# %%
reg.fit(X_train, Y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
predicts = reg.predict(X_test)

# %%
from sklearn import metrics
from sklearn.metrics import r2_score, mean_absolute_error
print("""
        Mean Squared Error: {}
        R2 Score: {}
        Mean Absolute Error: {}
     """.format(
        np.sqrt(metrics.mean_squared_error(Y_test, predicts)),
        r2_score(Y_test,predicts) * 100,
        mean_absolute_error(Y_test,predicts)
        ))
# Out:
#         Mean Squared Error: 6.72924316541526
#         R2 Score: 2.702539387332492
#         Mean Absolute Error: 5.596273412423612

# %%
error_hours = pd.DataFrame({
        'Actual Values': np.array(Y_test).flatten(),
        'Predicted Values': predicts.flatten()}).head(20)
error_hours.head(3)
# Out:
#    Actual Values  Predicted Values
# 0           20.0         14.269339
# 1           20.0         14.460032
# 2            8.0         14.211520

# %%
df = pd.read_csv('./crime.csv')

# %%
df['DATE'] = pd.to_datetime({'year':df['YEAR'], 'month':df['MONTH'], 'day':df['DAY']})

# %%
df = df.groupby('DATE').count()['TYPE'].to_frame()
print(df)
# Out:
#             TYPE
# DATE
# 2003-01-01   191
# 2003-01-02   148
# 2003-01-03   160
# 2003-01-04   146
# 2003-01-05   120
# ...          ...
# 2017-07-09   119
# 2017-07-10   100
# 2017-07-11   104
# 2017-07-12    96
# 2017-07-13    51
#
# [5308 rows x 1 columns]

# %%
df.reset_index(inplace=True)
df.columns = ['ds','y']
df.head()
# Out:
#           ds    y
# 0 2003-01-01  191
# 1 2003-01-02  148
# 2 2003-01-03  160
# 3 2003-01-04  146
# 4 2003-01-05  120

# %%
df_m1 = df.copy()

# %%
df_m1['y'] = np.log(df_m1['y'])
print(df_m1)
# Out:
#              ds         y
# 0    2003-01-01  5.252273
# 1    2003-01-02  4.997212
# 2    2003-01-03  5.075174
# 3    2003-01-04  4.983607
# 4    2003-01-05  4.787492
# ...         ...       ...
# 5303 2017-07-09  4.779123
# 5304 2017-07-10  4.605170
# 5305 2017-07-11  4.644391
# 5306 2017-07-12  4.564348
# 5307 2017-07-13  3.931826
#
# [5308 rows x 2 columns]

# %%
m1_plain = Prophet()
m1_plain.fit(df_m1)
future = m1_plain.make_future_dataframe(periods=365)
forecast_m1 = m1_plain.predict(future)
# Out:
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
m1_plain.plot(forecast_m1)

# %%
m1_plain.plot_components(forecast_m1)

# %%
y = df['y'].to_frame()
y.index = df['ds']
n = np.int(y.count())

# %%
forecast_m1_exp = np.exp(forecast_m1[['yhat']])
forecast_m1_exp.index = forecast_m1['ds']

# %%
error = forecast_m1_exp['yhat'] - y['y']
MAPE_m1 = (error/y['y']).abs().sum()/n *100
round(MAPE_m1,2)
# Out:
# 12.64

# %%
start = '2003-01-01'
end = '2003-01-05'
forecast_m1_exp[(forecast_m1_exp.index >= start) & (forecast_m1_exp.index <= end)].astype(int)
# Out:
#             yhat
# ds
# 2003-01-01   123
# 2003-01-02   126
# 2003-01-03   140
# 2003-01-04   143
# 2003-01-05   131
